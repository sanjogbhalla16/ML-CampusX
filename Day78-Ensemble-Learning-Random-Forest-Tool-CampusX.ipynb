# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  3.280450  0.784341  3.314659  2.267107  1.238047       0
# 1  1.872393 -0.292527  1.259025  1.924976  1.553132       0
# 2  2.154568 -1.010893  1.632928  1.257636  1.222549       0
# 3  1.511714 -0.439875  2.153949  1.297480  0.464738       0
# 4  0.695090 -0.919342  0.975661  0.923607  0.980216       0

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
sample_rows(df,0.1)
# Out:
#         col1      col2      col3      col4      col5  target
# 63  0.900660  2.574142 -0.580835 -1.559860  0.359450       1
# 96  0.409996  2.020634 -0.386216 -1.497933  2.723619       1
# 66  0.700369 -1.150452  1.186163  0.746016  0.596364       0
# 7   2.131113  0.128542  1.548650  1.730503  0.789529       0
# 17  2.144750  0.301379  2.572182  2.088717  1.117644       0
# 8   1.013619  2.610586 -2.325984 -0.833392  2.032218       1
# 43  2.774550 -2.403811 -2.675766  0.827478 -0.386468       1
# 1   1.872393 -0.292527  1.259025  1.924976  1.553132       0
# 18  3.235696  1.571960  3.084542  2.421800  1.720773       0
# 8   1.013619  2.610586 -2.325984 -0.833392  2.032218       1

# %%
# function for feature sampling
import random

def sample_features(df,percent):
  cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
  new_df = df[cols].copy()
  new_df['target'] = df['target']
  return new_df

# %%
cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))

# %%
int(percent*(df.shape[1]-1))

# %%
df.shape[1]-1
# Out:
# 5

# %%
df.columns.tolist()[:-1]
# Out:
# ['col1', 'col2', 'col3', 'col4', 'col5']

# %%
cols = random.sample(df.columns.tolist()[:-1],int(0.5*(df.shape[1]-1)))
cols
# Out:
# ['col5', 'col3']

# %%
# function for combined sampling

def combined_sampling(df,row_percent,col_percent):
  new_df = sample_rows(df,row_percent)
  return sample_features(new_df,col_percent)

# %%
df1 = sample_rows(df,0.2)
df1
# Out:
#         col1      col2      col3      col4      col5  target
# 30  0.408456  1.447532 -1.443344 -1.208947  2.374698       1
# 43  2.774550 -2.403811 -2.675766  0.827478 -0.386468       1
# 22  1.591999 -0.497175  1.284698  1.643651  1.221068       0
# 48  0.978522  0.985754  1.572212  1.909677  1.391932       0
# 55 -0.520641  1.746414 -0.517969 -0.225606  2.169354       1
# 39  0.674513 -2.005837  0.693849  0.710574  0.866993       0
# 99  2.526734 -2.004961 -1.456132 -1.350991 -0.156595       0
# 27  1.717649  1.213684 -0.030548 -2.124289 -0.276182       1
# 94  1.816519 -2.166119 -3.333304  0.117612  1.004993       1
# 47 -0.948989  1.959898  0.930467  1.168869  1.378435       1
# 36  1.357270 -1.877270  1.302435  0.587472  1.231602       0
# 65  2.069077  2.962733 -0.974887 -2.684792 -0.761121       1
# 66  0.700369 -1.150452  1.186163  0.746016  0.596364       0
# 66  0.700369 -1.150452  1.186163  0.746016  0.596364       0
# ...

# %%
df2 = sample_rows(df,0.2)
df2
# Out:
#         col1      col2      col3      col4      col5  target
# 95  1.561394  0.937192 -1.752061 -1.708634  0.120896       1
# 71 -1.402360  2.100974  1.051878 -0.259555  0.332069       1
# 86  0.707317 -0.838404  0.591256  0.753873  1.238327       0
# 23  1.566680 -0.405679  1.279725  1.404670  1.410758       0
# 86  0.707317 -0.838404  0.591256  0.753873  1.238327       0
# 85  0.041393  1.943579 -0.014944 -2.827850  1.478006       1
# 88 -0.534686 -1.403814  0.389539 -0.062789  0.631019       0
# 35 -1.843538  4.370536  1.548839 -1.356527  2.380067       1
# 91  1.001439 -0.311340 -1.441672 -0.805206  0.822804       1
# 31  0.365614 -1.182329  0.551078  0.665754  0.820233       0
# 33  0.654025  2.803524 -0.306713 -1.991519  0.740520       1
# 0   3.280450  0.784341  3.314659  2.267107  1.238047       0
# 46  0.817199  0.051579 -1.615021  0.857964  1.328063       1
# 23  1.566680 -0.405679  1.279725  1.404670  1.410758       0
# ...

# %%
df3 = sample_rows(df,0.2)
df3
# Out:
#         col1      col2      col3      col4      col5  target
# 31  0.365614 -1.182329  0.551078  0.665754  0.820233       0
# 21  1.325519  1.347205  1.807964  2.090384  1.569479       0
# 37  0.497537  1.729406 -0.989867 -0.093598 -0.771904       1
# 77  0.486790 -0.937392  0.557481  0.748948  0.786094       0
# 0   3.280450  0.784341  3.314659  2.267107  1.238047       0
# 63  0.900660  2.574142 -0.580835 -1.559860  0.359450       1
# 35 -1.843538  4.370536  1.548839 -1.356527  2.380067       1
# 89 -1.578770 -2.676326 -0.622007 -0.659453  0.229823       0
# 73  2.770201 -0.178983 -3.891352  0.025784  1.036575       1
# 27  1.717649  1.213684 -0.030548 -2.124289 -0.276182       1
# 34  0.243536  0.755421 -0.174842 -1.884772  1.784299       1
# 25  1.051826  2.621524 -0.364247 -3.188220  0.934058       1
# 62  3.063003 -0.517027 -2.230389 -1.131619  0.726940       1
# 60 -1.908698  1.698257 -0.448973  0.821807  3.913711       1
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'target'], dtype='object')
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'target'], dtype='object')
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'target'], dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[1] <= 1.1\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.4, 0.5, 'x[2] <= -2.066\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 0.187\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[1] <= 1.443\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[1] <= -0.727\ngini = 0.42\nsamples = 20\nvalue = [6, 14]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.523\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
clf1.predict(np.array([1.872393, -0.292527, 1.259025, 1.924976, 1.553132]).reshape(1,5)) # 0
# Out:
# c:\Users\Sanjog Bhalla\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([1.872393, -0.292527, 1.259025, 1.924976, 1.553132]).reshape(1,5)) # 0
# Out:
# c:\Users\Sanjog Bhalla\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([1.872393, -0.292527, 1.259025, 1.924976, 1.553132]).reshape(1,5)) # 0
# Out:
# c:\Users\Sanjog Bhalla\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df.sample(14,replace=True)
# Out:
#         col1      col2      col3      col4      col5  target
# 28  1.736191 -2.876637 -2.835533  4.780593  0.680190       1
# 93 -0.865411 -2.545200 -0.642229 -0.058620  0.705546       0
# 16  3.056422  0.905159  2.893912  2.075172  2.022969       0
# 81  0.203062  0.881477 -0.955333 -0.259875  1.142513       1
# 78  0.501629 -1.592532  0.149671  0.733746  0.712898       0
# 18  3.235696  1.571960  3.084542  2.421800  1.720773       0
# 97  1.259005  2.411375 -1.798303 -2.360382  2.396634       1
# 20  3.588482 -1.332130 -2.023502 -2.678491 -1.365612       1
# 21  1.325519  1.347205  1.807964  2.090384  1.569479       0
# 77  0.486790 -0.937392  0.557481  0.748948  0.786094       0
# 91  1.001439 -0.311340 -1.441672 -0.805206  0.822804       1
# 56  0.800336 -1.369827  0.624277  0.950090  0.888823       0
# 25  1.051826  2.621524 -0.364247 -3.188220  0.934058       1
# 74  1.008630  1.796019 -0.724394  0.955219  0.107902       1
