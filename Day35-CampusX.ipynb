# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_science_job.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df.isnull().sum() #no of missing values
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
#how many percent of missing values
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.shape
# Out:
# (19158, 13)

# %%
#we will take all the columns where only the mean is < 0.05 percent for CCA
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 9645                    0.624    Full time course        Graduate         4.0
# 2872                    0.920    Full time course        Graduate         0.0
# 13971                   0.920       no_enrollment        Graduate         5.0
# 6107                    0.624    Full time course        Graduate         4.0
# 14354                   0.910       no_enrollment         Masters         9.0
#
#        training_hours
# 9645              NaN
# 2872             31.0
# 13971            34.0
# 6107            112.0
# 14354             8.0

# %%
# we need to find if we remove all the rows from our org dataset from above these columns then how much difference in data will come
# len(df[cols].dropna()) / len(df)
# len(df) # this will give no of rows
len(df[cols].dropna()) / len(df)
# Out:
# 0.8968577095730244

# %%
new_df = df[cols].dropna()
df.shape, new_df.shape
# Out:
# ((19158, 13), (17182, 5))

# %%
new_df.hist(bins=50, density=True, figsize=(12, 12))
plt.show()

# %%
#if you have performed CCA on numerical data then plot histogram over it
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

#original data
df['training_hours'].hist(bins=50, ax=ax1, density=True, color='red')

#now on new data
new_df['training_hours'].hist(bins=50, ax=ax2, density=True, color='green')
plt.show()

# %%
#the overlapping figure
fig = plt.figure()
ax = fig.add_subplot(111)

#original data
df['training_hours'].hist(bins=50, ax=ax, density=True, color='red')

#data after cca, the argument alpha makes the color transparent, so we can see the overlap of the 2 distribution 
#now on new data
new_df['training_hours'].hist(bins=50, ax=ax, density=True, color='green', alpha=0.8)
# Out:
# <Axes: >

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

#original data
df['training_hours'].plot.density(color='red', ax=ax1)

#now on new data
new_df['training_hours'].plot.density(color='green', ax=ax2)
plt.show()

# %%
#the overlapping figure
fig = plt.figure()
ax = fig.add_subplot(111)

#original data
df['training_hours'].plot.density(color='red')

#data after cca
new_df['training_hours'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
#for city development index
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

#original data
df['city_development_index'].hist(bins=50, ax=ax1, density=True, color='red')

#now on new data
new_df['city_development_index'].hist(bins=50, ax=ax2, density=True, color='green')
plt.show()

# %%
#the overlapping figure
fig = plt.figure()
ax = fig.add_subplot(111)

#original data
df['city_development_index'].hist(bins=50, ax=ax, density=True, color='red')

#data after cca, the argument alpha makes the color transparent, so we can see the overlap of the 2 distribution 
#now on new data
new_df['city_development_index'].hist(bins=50, ax=ax, density=True, color='green', alpha=0.8)
# Out:
# <Axes: >

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

#original data
df['city_development_index'].plot.density(color='red', ax=ax1)

#now on new data
new_df['city_development_index'].plot.density(color='green', ax=ax2)
plt.show()

# %%
#the overlapping figure
fig = plt.figure()
ax = fig.add_subplot(111)

#original data
df['city_development_index'].plot.density(color='red')

#data after cca
new_df['city_development_index'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
#for experience
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

#original data
df['experience'].hist(bins=50, ax=ax1, density=True, color='red')

#now on new data
new_df['experience'].hist(bins=50, ax=ax2, density=True, color='green')
plt.show()

# %%
#the overlapping figure
fig = plt.figure()
ax = fig.add_subplot(111)

#original data
df['experience'].hist(bins=50, ax=ax, density=True, color='red')

#data after cca, the argument alpha makes the color transparent, so we can see the overlap of the 2 distribution 
#now on new data
new_df['experience'].hist(bins=50, ax=ax, density=True, color='green', alpha=0.8)
# Out:
# <Axes: >

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

#original data
df['experience'].plot.density(color='red', ax=ax1)

#now on new data
new_df['experience'].plot.density(color='green', ax=ax2)
plt.show()

# %%
#the overlapping figure
fig = plt.figure()
ax = fig.add_subplot(111)

#original data
df['experience'].plot.density(color='red')

#data after cca
new_df['experience'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
#Now the Categorical Data
df['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       13817
# Full time course     3757
# Part time course     1198
# Name: count, dtype: int64

# %%
#for Education
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
#the ratio before of these categories == needs to be same after performing CCA
temp = pd.concat([
    # percentage of observations per category, original data
    df['enrolled_university'].value_counts() / len(df),
    
    # percentage of observation per category, cca data
    new_df['enrolled_university'].value_counts() / len(df)
], axis=1)

#ass columns names
temp.columns = ['original','cca']

temp
# Out:
#                      original       cca
# enrolled_university
# no_enrollment        0.721213  0.659359
# Full time course     0.196106  0.180029
# Part time course     0.062533  0.057469

# %%
temp = pd.concat([
    # percentage of observations per category, original data
    df['education_level'].value_counts() / len(df),
    
    # percentage of observation per category, cca data
    new_df['education_level'].value_counts() / len(df)
], axis=1)

#ass columns names
temp.columns = ['original','cca']

temp
# Out:
#                  original       cca
# education_level
# Graduate         0.605387  0.555904
# Masters          0.227633  0.209938
# High School      0.105282  0.096304
# Phd              0.021610  0.019835
# Primary School   0.016077  0.014876
