# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)  
print(y.shape)  # type: ignore
# Out:
# (442, 10)
# (442,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568969

# %%
import random
class MBGDRegressor:
    
    def __init__(self,batch_size,learning_rate=0.01,epochs=100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        
    def fit(self,X_train,y_train):
        #initialize your coefs
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            # we need to loop in epochs and divide the rows into batches and then loop on the batches
            for j in range(int(X_train.shape[0]/self.batch_size)): # this will run on number of batches 
                
                random_idx_in_batches = random.sample(range(X_train.shape[0]),self.batch_size)  # this will take 10 random values,one from each batch
                
                #now for this particular random index we need to find the y_pred
                y_hat = np.dot(X_train[random_idx_in_batches],self.coef_) + self.intercept_ # type: ignore this will be a matrix
                
                intercept_der = -2 * np.mean(y_train[random_idx_in_batches] - y_hat) # derivative w.r.t intercept , we need mean here
                
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)
                
                coef_der = -2 * np.dot((y_train[random_idx_in_batches] - y_hat),X_train[random_idx_in_batches]) # derivative w.r.t coef
                self.coef_ = self.coef_ - (self.lr * coef_der)
        
        print(self.intercept_,self.coef_)
        
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_ # type: ignore , y = mx + b

# %%
import random
random.sample(range(1,100),10)
# Out:
# [77, 6, 31, 86, 58, 75, 21, 85, 24, 46]

# %%
mbr = MBGDRegressor(batch_size=X_train.shape[0]//10, learning_rate=0.01,epochs=100)

# %%
X_train.shape[0]/10
# Out:
# 35.3

# %%
mbr.fit(X_train,y_train)
# Out:
# 151.7512635455384 [  38.0817262  -150.08612323  453.62296562  306.68435146  -22.33980652
#   -90.85568048 -192.18296596  111.34431022  410.27878737  114.59965771]

# %%
y_pred = mbr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.45352470811173917
