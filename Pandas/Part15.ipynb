# %%
import numpy as np
import pandas as pd

# %%
food_data = pd.read_csv('food.csv')

# %%
food_data
# Out:
#       Name Gender     City Frequency     Item   Spends
# 0   Nitish      M  Kolkata    Weekly    Burger      11
# 1      Anu      F  Gurgaon     Daily  Sandwich      14
# 2    Mukku      M  Kolkata      Once      Vada      25
# 3     Suri      M  Kolkata   Monthly     Pizza      56
# 4    Rajiv      M    Patna     Never    Paneer      34
# 5   Nitish      M  Kolkata    Weekly    Burger      11
# 6      Anu      F  Gurgaon     Daily  Sandwich      14
# 7    Mukku      M  Kolkata      Once      Vada      25
# 8     Suri      M  Kolkata   Monthly     Pizza      56
# 9    Rajiv      M    Patna     Never    Paneer      34
# 10  Nitish      M  Kolkata    Weekly    Burger      11
# 11     Anu      F  Gurgaon     Daily  Sandwich      14
# 12   Mukku      M  Kolkata      Once      Vada      25
# 13    Suri      M  Kolkata   Monthly     Pizza      56
# 14   Rajiv      M    Patna     Never    Paneer      34
# 15  Nitish      M  Kolkata    Weekly    Burger      11
# ...

# %%
food_data.pivot_table(index='City', columns= 'Item', values='Spends', aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 food_data.pivot_table(index='City', columns= 'Item', values='Spends', aggfunc='mean')
#
# File c:\Users\Sanjog Bhalla\anaconda3\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
# ...

# %%
print(food_data.columns)
# Out:
# Index(['Name', 'Gender', 'City', 'Frequency', 'Item ', 'Spends'], dtype='object')

# %%
food_data.pivot_table(index='City', columns='Item ', values='Spends', aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 food_data.pivot_table(index='City', columns='Item ', values='Spends', aggfunc='mean')
#
# NameError: name 'food_data' is not defined
