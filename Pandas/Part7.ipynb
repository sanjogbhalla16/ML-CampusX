# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('matches - matches.csv') #only the name is fine if the file is in the same directory

# %%
#the Pandas Plotting Library is built on top of Matplotlib
#plot a bar chart 
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head(5).plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
#we have a column name as toss decision
data['toss_decision'].value_counts()
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#we have a column as win by runs
data['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
